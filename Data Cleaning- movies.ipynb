# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import re
from datetime import date
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
data = pd.read_csv("movies.csv")
data
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
data.shape
# Out:
# (9999, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
data.isnull().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %%
#data['YEAR']=data['YEAR'].str.strip(')')

# %%
#data['YEAR']=data['YEAR'].str.strip('(')
data
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
#data['YEAR']=data['YEAR'].str.strip(' ')

# %%
#data['YEAR']=data['YEAR'].str.strip('-')

# %%
data
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
#data['YEAR']=str(data['YEAR'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
data['YEAR']= data['YEAR'].str.strip(' -()')

data
# Out:
#                                    MOVIES       YEAR  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation      2021–
# 2                        The Walking Dead  2010–2022
# 3                          Rick and Morty      2013–
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9994                       The Imperfects      2021–
# 9995                               Arcane      2021–
# 9996                    Heart of Invictus      2022–
# 9997                       The Imperfects      2021–
# 9998                       The Imperfects      2021–
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
#data['start_year'],data['end_year']=
df=data['YEAR'].str.split('–', expand=True)
df
# Out:
#          0     1
# 0     2021  None
# 1     2021
# 2     2010  2022
# 3     2013
# 4     2021  None
# ...    ...   ...
# 9994  2021
# 9995  2021
# 9996  2022
# 9997  2021
# 9998  2021
#
# [9999 rows x 2 columns]

# %%
data['start_date']=df[0]
data['end_date']=df[1]
data
# Out:
#                                    MOVIES       YEAR  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation      2021–
# 2                        The Walking Dead  2010–2022
# 3                          Rick and Morty      2013–
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9994                       The Imperfects      2021–
# 9995                               Arcane      2021–
# 9996                    Heart of Invictus      2022–
# 9997                       The Imperfects      2021–
# 9998                       The Imperfects      2021–
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
data.drop('YEAR',inplace=True,axis=1)

# %%
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# ...

# %%
todays_date = date.today()
current_year = todays_date.year
data.end_date.fillna(current_year,inplace= True)
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MOVIES      9999 non-null   object
#  1   GENRE       9919 non-null   object
#  2   RATING      8179 non-null   float64
#  3   ONE-LINE    9999 non-null   object
#  4   STARS       9999 non-null   object
#  5   VOTES       8179 non-null   object
#  6   RunTime     7041 non-null   float64
#  7   Gross       460 non-null    object
#  8   start_date  9355 non-null   object
#  9   end_date    9999 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 781.3+ KB

# %%
data.isnull().sum()
# Out:
# MOVIES           0
# GENRE           80
# RATING        1820
# ONE-LINE         0
# STARS            0
# VOTES         1820
# RunTime       2958
# Gross         9539
# start_date     644
# end_date         0
# dtype: int64

# %%
data = data.replace(r'^\s*$', np.nan, regex=True)
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# ...

# %%
data.end_date.fillna(current_year,inplace=True)
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# ...

# %%
data.dropna(subset=['start_date'],inplace=True)

# %%
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# ...

# %%
data.isnull().sum()
# Out:
# MOVIES           0
# GENRE           39
# RATING        1176
# ONE-LINE         0
# STARS          258
# VOTES         1176
# RunTime       2342
# Gross         8895
# start_date       0
# end_date         0
# dtype: int64

# %%
data.drop(['Gross'],inplace=True,axis=1)

# %%
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# ...

# %%
runt_mode = data.RunTime.mode()[0]
data.RunTime.fillna(runt_mode, inplace = True)
data.RunTime.isnull().sum()
# Out:
# 0

# %%
rating_mode = data.RATING.mode()[0]
data.RATING.fillna(rating_mode, inplace = True)
data.RATING.isnull().sum()
# Out:
# 0

# %%
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 7.2
# ...                                          ...     ...
# ...

# %%
data['GENRE']=data['GENRE'].str.strip('\n')

# %%
data['ONE-LINE']=data['ONE-LINE'].str.strip('\n')

# %%
data['STARS']=data['STARS'].str.strip('\n')

# %%
data['STARS']=data['STARS'].str.strip(' ')

# %%
data['STARS']=data['STARS'].str.strip('\n')

# %%
data = data.replace(r'\n',' ', regex=True)

# %%
data = data.replace(r',','', regex=True)

# %%
data.isnull().sum()
# Out:
# MOVIES          0
# GENRE           0
# RATING          0
# ONE-LINE        0
# STARS           0
# VOTES         983
# RunTime         0
# start_date      0
# end_date        0
# dtype: int64

# %%
data.dropna(subset=['STARS'],inplace=True)

# %%
data.dropna(subset=['GENRE'],inplace=True)

# %%
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9993                            Totenfrau
# 9994                       The Imperfects
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                        GENRE  RATING  \
# 0         Action Horror Thriller                 6.1
# 1     Animation Action Adventure                 5.0
# 2          Drama Horror Thriller                 8.2
# 3     Animation Adventure Comedy                 9.2
# 4            Action Crime Horror                 7.2
# ...                                      ...     ...
# 9993              Drama Thriller                 7.2
# ...

# %%
data.isnull().sum()
# Out:
# MOVIES          0
# GENRE           0
# RATING          0
# ONE-LINE        0
# STARS           0
# VOTES         983
# RunTime         0
# start_date      0
# end_date        0
# dtype: int64

# %%
data.VOTES = data.VOTES.astype('float64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9068 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MOVIES      9068 non-null   object
#  1   GENRE       9068 non-null   object
#  2   RATING      9068 non-null   float64
#  3   ONE-LINE    9068 non-null   object
#  4   STARS       9068 non-null   object
#  5   VOTES       8085 non-null   float64
#  6   RunTime     9068 non-null   float64
#  7   start_date  9068 non-null   object
#  8   end_date    9068 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 708.4+ KB

# %%
vote_median = data.VOTES.median()
data.VOTES.fillna(vote_median, inplace = True)
data.VOTES.isnull().sum()
# Out:
# 0

# %%
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9993                            Totenfrau
# 9994                       The Imperfects
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                        GENRE  RATING  \
# 0         Action Horror Thriller                 6.1
# 1     Animation Action Adventure                 5.0
# 2          Drama Horror Thriller                 8.2
# 3     Animation Adventure Comedy                 9.2
# 4            Action Crime Horror                 7.2
# ...                                      ...     ...
# 9993              Drama Thriller                 7.2
# ...

# %%
df1=data['STARS'].str.split('|', expand=True)
df1
# Out:
#                                                       0  \
# 0                            Director: Peter Thorwarth
# 1         Stars: Chris Wood  Sarah Michelle Gellar  ...
# 2         Stars: Andrew Lincoln  Norman Reedus  Meli...
# 3         Stars: Justin Roiland  Chris Parnell  Spen...
# 4                      Director: Matthias Schweighöfer
# ...                                                 ...
# 9993                           Director: Nicolai Rohde
# 9994      Stars: Morgan Taylor Campbell  Chris Cope ...
# 9996                   Director: Orlando von Einsiedel
# 9997                        Director: Jovanka Vuckovic
# 9998                        Director: Jovanka Vuckovic
#
#                                                       1
# 0           Stars: Peri Baumeister  Carl Anton Koch ...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# ...

# %%
data['Director']=df1[0]
data['Stars']=df1[1]
data
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9993                            Totenfrau
# 9994                       The Imperfects
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                        GENRE  RATING  \
# 0         Action Horror Thriller                 6.1
# 1     Animation Action Adventure                 5.0
# 2          Drama Horror Thriller                 8.2
# 3     Animation Adventure Comedy                 9.2
# 4            Action Crime Horror                 7.2
# ...                                      ...     ...
# 9993              Drama Thriller                 7.2
# ...

# %%
data.isnull().sum()
# Out:
# MOVIES           0
# GENRE            0
# RATING           0
# ONE-LINE         0
# STARS            0
# VOTES            0
# RunTime          0
# start_date       0
# end_date         0
# Director         0
# Stars         3200
# dtype: int64

# %%
data.dropna(subset=['Stars'],inplace=True)

# %%
data.isnull().sum()
# Out:
# MOVIES        0
# GENRE         0
# RATING        0
# ONE-LINE      0
# STARS         0
# VOTES         0
# RunTime       0
# start_date    0
# end_date      0
# Director      0
# Stars         0
# dtype: int64

# %%
data.drop(['STARS'],inplace=True,axis=1)

# %%
data
# Out:
#                                MOVIES                                  GENRE  \
# 0                       Blood Red Sky     Action Horror Thriller
# 4                     Army of Thieves        Action Crime Horror
# 6     The Last Letter from Your Lover              Drama Romance
# 10                Gunpowder Milkshake  Action Adventure Thriller
# 12                  Fear Street: 1994       Drama Horror Mystery
# ...                               ...                                    ...
# 9985                 The Last Kingdom       Action Drama History
# 9993                        Totenfrau             Drama Thriller
# 9996                Heart of Invictus          Documentary Sport
# 9997                   The Imperfects    Adventure Drama Fantasy
# 9998                   The Imperfects    Adventure Drama Fantasy
#
#       RATING                                           ONE-LINE    VOTES  \
# 0        6.1  A woman with a mysterious illness is forced in...  21062.0
# ...
